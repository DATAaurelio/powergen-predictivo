# %%
# Convertir el archivo Jupyter Notebook a PDF y HTML para generar el informe final
# !jupyter nbconvert --to pdf /mnt/batch/tasks/shared/LS_root/mounts/clusters/aurelio-parra/code/Users/aurelio.sosa.netmind/powergen-predictivo/modulo_2/src/reto_2.ipynb --output "/mnt/batch/tasks/shared/LS_root/mounts/clusters/aurelio-parra/code/Users/aurelio.sosa.netmind/powergen-predictivo/modulo_2/CSV/Informe_Final"
# !jupyter nbconvert --to html /mnt/batch/tasks/shared/LS_root/mounts/clusters/aurelio-parra/code/Users/aurelio.sosa.netmind/powergen-predictivo/modulo_2/src/reto_2.ipynb --output "/mnt/batch/tasks/shared/LS_root/mounts/clusters/aurelio-parra/code/Users/aurelio.sosa.netmind/powergen-predictivo/modulo_2/CSV/Informe_Final"
# Out:
# [NbConvertApp] Converting notebook /mnt/batch/tasks/shared/LS_root/mounts/clusters/aurelio-parra/code/Users/aurelio.sosa.netmind/powergen-predictivo/modulo_2/src/reto_2.ipynb to pdf
# [NbConvertApp] ERROR | Error while converting '/mnt/batch/tasks/shared/LS_root/mounts/clusters/aurelio-parra/code/Users/aurelio.sosa.netmind/powergen-predictivo/modulo_2/src/reto_2.ipynb'
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/nbconvert/exporters/templateexporter.py", line 386, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
# ...
